# %% [markdown]
# ![image.png](attachment:926e2daf-7e94-42a1-9cc6-68c5fd794fbf.png)

# %%
ord('A')
# Out:
# 65

# %%
ord(' ')
# Out:
# 32

# %%
ord('a')
# Out:
# 97

# %%
ord('%')
# Out:
# 37

# %%
ord('1')
# Out:
# 49

# %%
ord('\n')
# Out:
# 10

# %%
ord('G')
# Out:
# 71

# %%
import socket

mysock = socket.socket (socket.AF_INET , socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org' , 80))

cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode() # makes the string to Bytes encoded in UTF-8
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1 :
        break
    print (data.decode()) #here decode goes from Bytes to Unicode i.e. String in python3
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Sun, 29 Jan 2023 08:54:46 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already s
# ick and pale with grief

# %% [markdown]
# ![image.png](attachment:30447081-1609-4bc6-9164-20d29f606ff9.png)

# %% [markdown]
# below is the simplified explaination

# %% [markdown]
# ![image.png](attachment:9116581e-0be9-4706-b2c7-615d670524e5.png)
