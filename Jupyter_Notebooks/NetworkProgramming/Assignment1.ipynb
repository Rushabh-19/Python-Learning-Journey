# %% [markdown]
# ![image.png](attachment:930ede23-c18a-4c42-af4d-f44529d57acb.png)

# %%
import urllib.request, urllib.parse , urllib.error
from bs4 import BeautifulSoup
import re

url = input ('Enter - ') #Ask for URL
html = urllib.request.urlopen(url).read()

soup = BeautifulSoup(html , 'html.parser') 
#print ('---------------\n{}-----------------'.format(soup))

tags = soup ('span') 
count = 0
for tag in tags:
    #print (re.findall('[0-9]+',tag.decode()))
    numbers = re.findall('[0-9]+',tag.decode())
    for num in numbers:
        count += int(num)
print (count)
# Out:
# Enter -  http://py4e-data.dr-chuck.net/comments_1687016.html
# 2114
