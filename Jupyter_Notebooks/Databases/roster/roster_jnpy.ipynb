# %%
import json
import sqlite3

conn = sqlite3.connect('rosterdb.sqlite')
curr = conn.cursor()

#lets setup a executescrupt()

curr.executescript('''
      DROP TABLE IF EXISTS User;
      DROP TABLE IF EXISTS Course;
      DROP TABLE IF EXISTS Member;
      
      CREATE TABLE User(
          id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
          name TEXT UNIQUE
      );
      
      CREATE TABLE Course(
          id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
          title TEXT UNIQUE
      );
      
      CREATE TABLE Member(
          user_id INTEGER,
          course_id INTEGER,
          role INTEGER,
          PRIMARY KEY (user_id, course_id)
      );
''')

fname = input ('Enter the file name:')
if len(fname) < 1: fname = 'roster_data.json'
    
# [
#    ["Charley", "sill0", 1],
#    ["Mea", "sill0", 0], 

str_data = open (fname).read()
json_data = json.loads(str_data)

for entry in json_data:
    name = entry[0]
    title = entry[1]
    role = entry[2]
    
    print(f'name: {name}, title: {title}, role: {role}')
    
    curr.execute('''INSERT OR IGNORE INTO User (name)
          VALUES(?)''', (name, ))
    curr.execute('''SELECT id FROM User WHERE name = ?''', (name, ))
    user_id = curr.fetchone()[0]
    
    curr.execute('''INSERT OR IGNORE INTO Course (title)
    VALUES(?)''', (title, ))
    curr.execute('''SELECT id FROM Course WHERE title = ?''', (title, ))
    course_id = curr.fetchone()[0]
    
    curr.execute('''INSERT OR REPLACE INTO Member (user_id, course_id, role)
    VALUES(?, ?, ?)''', (user_id, course_id, role))
    
    conn.commit()
# Out:
# Enter the file name:
# name: Kassia, title: si110, role: 1
# name: Charles, title: si110, role: 0
# name: Rosanna, title: si110, role: 0
# name: Demi, title: si110, role: 0
# name: Logyne, title: si110, role: 0
# name: Cameron, title: si110, role: 0
# name: Lawrie, title: si110, role: 0
# name: Ryhanna, title: si110, role: 0
# name: Schekina, title: si110, role: 0
# name: Sasha, title: si110, role: 0
# name: Demira, title: si110, role: 0
# name: Ciar, title: si110, role: 0
# name: Alighia, title: si110, role: 0
# name: Lotta, title: si110, role: 0
# name: Ijay, title: si110, role: 0
# name: Courtneylee, title: si110, role: 0
# name: Keris, title: si110, role: 0
# name: Saiorse, title: si110, role: 0
# name: Crystal, title: si110, role: 0
# name: Shaye, title: si110, role: 0
# name: Harvinder, title: si110, role: 0
# name: Zalfa, title: si110, role: 0
# name: Alf, title: si110, role: 0
# name: Momin, title: si110, role: 0
# name: Analucia, title: si110, role: 0
# name: Rhiannnon, title: si110, role: 0
# name: Sonneey, title: si106, role: 1
# name: Areej, title: si106, role: 0
# name: Monty, title: si106, role: 0
# name: Elliott, title: si106, role: 0
# name: Alaa, title: si106, role: 0
# name: Greer, title: si106, role: 0
# name: Kiranpreet, title: si106, role: 0
# name: Sahbian, title: si106, role: 0
# name: Diarmuid, title: si106, role: 0
# name: Tyrone, title: si106, role: 0
# name: Abubakar, title: si106, role: 0
# name: Rupert, title: si106, role: 0
# name: Kasey, title: si106, role: 0
# name: Wen, title: si106, role: 0
# name: Soma, title: si106, role: 0
# name: Fearne, title: si106, role: 0
# name: Sasha, title: si106, role: 0
# name: Calypso, title: si106, role: 0
# name: Tammam, title: si106, role: 0
# name: Kailyn, title: si106, role: 0
# name: Aylesha, title: si106, role: 0
# name: Sukhveer, title: si106, role: 0
# name: Danika, title: si106, role: 0
# name: Rahil, title: si106, role: 0
# name: Eliana, title: si106, role: 0
# name: Laia, title: si106, role: 0
# name: Sephiroth, title: si106, role: 0
# name: Ayrton, title: si106, role: 0
# name: Niome, title: si106, role: 0
# name: Abdisalam, title: si106, role: 0
# name: Katelin, title: si106, role: 0
# name: Marybeth, title: si106, role: 0
# name: Malisa, title: si106, role: 0
# name: Naisha, title: si106, role: 0
# name: Aliya, title: si106, role: 0
# name: Name, title: si106, role: 0
# name: Tigan, title: si106, role: 0
# name: Rhanna, title: si106, role: 0
# name: Shiloh, title: si106, role: 0
# name: Finnan, title: si206, role: 1
# name: Exodi, title: si206, role: 0
# name: Pippa, title: si206, role: 0
# name: Eliane, title: si206, role: 0
# name: Madelyn, title: si206, role: 0
# name: Jasmina, title: si206, role: 0
# name: Jackie, title: si206, role: 0
# name: Tanya, title: si206, role: 0
# name: Areej, title: si206, role: 0
# name: Ramandeep, title: si206, role: 0
# name: Abrar, title: si206, role: 0
# name: Lacci, title: si206, role: 0
# name: Salahudin, title: si206, role: 0
# name: Zamaar, title: si206, role: 0
# name: Kalani, title: si206, role: 0
# name: Callie, title: si206, role: 0
# name: Shreyas, title: si206, role: 0
# name: Reuben, title: si206, role: 0
# name: Haniyah, title: si301, role: 1
# name: Ayleigh, title: si301, role: 0
# name: Stacy, title: si301, role: 0
# name: Nima, title: si301, role: 0
# name: Baylie, title: si301, role: 0
# name: Tianqi, title: si301, role: 0
# name: Justinas, title: si301, role: 0
# name: Gregor, title: si301, role: 0
# name: Sweyn, title: si301, role: 0
# name: Arved, title: si301, role: 0
# name: Cephas, title: si301, role: 0
# name: Eliane, title: si301, role: 0
# name: Abhisumant, title: si301, role: 0
# name: Airlie, title: si301, role: 0
# name: Teagan, title: si301, role: 0
# name: Keiran, title: si301, role: 0
# name: Geoff, title: si301, role: 0
# name: Kaitlan, title: si301, role: 0
# name: Zennon, title: si301, role: 0
# name: Milosz, title: si301, role: 0
# name: Moray, title: si301, role: 0
# name: Jada, title: si301, role: 0
# name: Maighdlin, title: si301, role: 0
# name: Daithi, title: si301, role: 0
# name: Ines, title: si301, role: 0
# name: Chiron, title: si310, role: 1
# name: Ayan, title: si310, role: 0
# name: Danyal, title: si310, role: 0
# name: Benji, title: si310, role: 0
# name: Mira, title: si310, role: 0
# name: Libbie, title: si310, role: 0
# name: Alix, title: si310, role: 0
# name: Sajjad, title: si310, role: 0
# name: Amaia, title: si310, role: 0
# name: Zaki, title: si310, role: 0
# name: Simbiat, title: si310, role: 0
# name: Breogan, title: si310, role: 0
# name: Danika, title: si310, role: 0
# name: Taysia, title: si310, role: 0
# name: Cayce, title: si310, role: 0
# name: Paul, title: si310, role: 0
# name: Harvinder, title: si310, role: 0
# name: Nuada, title: si310, role: 0
# name: MacCartney, title: si310, role: 0
# name: Kaelin, title: si310, role: 0
# name: Yoji, title: si310, role: 0
# name: Hussan, title: si310, role: 0
# name: Gabriella, title: si310, role: 0
# name: Kasandra, title: si310, role: 0
# name: Rheo, title: si310, role: 0
# name: Diesil, title: si310, role: 0
# name: Agnieszka, title: si310, role: 0
# name: Anabelle, title: si310, role: 0
# name: Kaydyne, title: si310, role: 0
# name: Jun, title: si310, role: 0
# name: Dougal, title: si310, role: 0
# name: Dimitri, title: si310, role: 0
# name: Caelainn, title: si310, role: 0
# name: Windsor, title: si310, role: 0
# name: Lmar, title: si310, role: 0
# name: Leyre, title: si310, role: 0
# name: Maude, title: si310, role: 0
# name: Yasin, title: si310, role: 0
# name: Shivani, title: si310, role: 0
# name: Annmarie, title: si310, role: 0
# name: Millie, title: si310, role: 0
# name: Dmitri, title: si310, role: 0
# name: Ricards, title: si310, role: 0
# name: Jordin, title: si310, role: 0
# name: Kaelum, title: si310, role: 0
# name: Fasai, title: si310, role: 0
# name: Karmen, title: si310, role: 0
# name: Jane, title: si310, role: 0
# name: Lotus, title: si310, role: 0
# name: Terri, title: si310, role: 0
# name: Aby, title: si334, role: 1
# name: Rylan, title: si334, role: 0
# name: Jordyn, title: si334, role: 0
# name: Carys, title: si334, role: 0
# name: Matas, title: si334, role: 0
# name: Alora, title: si334, role: 0
# name: Tianqi, title: si334, role: 0
# name: Zendel, title: si334, role: 0
# name: Sofian, title: si334, role: 0
# name: Leigh, title: si334, role: 0
# name: Oryn, title: si334, role: 0
# name: Believe, title: si334, role: 0
# name: Lexi, title: si334, role: 0
# name: Corrie, title: si334, role: 0
# name: Sonni, title: si334, role: 0
# name: Stephen, title: si334, role: 0
# name: Cameryn, title: si334, role: 0
# name: Mirryn, title: si334, role: 0
# name: Moya, title: si334, role: 0
# name: Kasper, title: si334, role: 0
# name: Katrin, title: si334, role: 0
# name: Peebles, title: si334, role: 0
# name: Elora, title: si334, role: 0
# name: Loukas, title: si334, role: 0
# name: Juan, title: si334, role: 0
# name: Cephas, title: si334, role: 0
# name: Autumn, title: si334, role: 0
# name: Yelena, title: si334, role: 0
# name: Aaren, title: si334, role: 0
# name: Jiayi, title: si334, role: 0
# name: Natalia, title: si334, role: 0
# name: Teo, title: si334, role: 0
# name: Colum, title: si334, role: 0
# name: Miah, title: si334, role: 0
# name: Leno, title: si334, role: 0
# name: Gustav, title: si334, role: 0
# name: Calder, title: si334, role: 0
# name: Sahil, title: si334, role: 0
# name: Samanta, title: si334, role: 0
# name: Clio, title: si334, role: 0
# name: Ksawier, title: si363, role: 1
# name: Chardonnay, title: si363, role: 0
# name: Damaris, title: si363, role: 0
# name: Symon, title: si363, role: 0
# name: Carlie, title: si363, role: 0
# name: Tammi, title: si363, role: 0
# name: Alani, title: si363, role: 0
# name: Hassan, title: si363, role: 0
# name: Lael, title: si363, role: 0
# name: Berkay, title: si363, role: 0
# name: Rihanna, title: si363, role: 0
# name: Bryce, title: si363, role: 0
# name: Courtneylee, title: si363, role: 0
# name: Aidian, title: si363, role: 0
# name: Maryam, title: si363, role: 0
# name: Bony, title: si363, role: 0
# name: Machaela, title: si363, role: 0
# name: Jordyn, title: si363, role: 0
# name: Favour, title: si363, role: 0
# name: Lorraine, title: si363, role: 0
# name: Conner, title: si363, role: 0
# name: Loghan, title: si363, role: 0
# name: Mathuyan, title: si363, role: 0
# name: Murron, title: si363, role: 0
# name: Zubair, title: si363, role: 0
# name: Abbigale, title: si363, role: 0
# name: Fruin, title: si363, role: 0
# name: Corin, title: si363, role: 0
# name: Sadie, title: si363, role: 0
# name: Indi, title: si363, role: 0
# name: Ghalya, title: si363, role: 0
# name: Nikodem, title: si363, role: 0
# name: Milo, title: si363, role: 0
# name: Aya, title: si363, role: 0
# name: Nuada, title: si363, role: 0
# name: Maci, title: si363, role: 0
# name: Sona, title: si363, role: 0
# name: Wilson, title: si363, role: 0
# name: Kayda, title: si363, role: 0
# name: Eisa, title: si363, role: 0
# name: Exodi, title: si363, role: 0
# name: Isha, title: si363, role: 0
# name: Romana, title: si363, role: 0
# name: Sky, title: si363, role: 0
# name: Luca, title: si363, role: 0
# name: Shazil, title: si363, role: 0
# name: Anabella, title: si363, role: 0
# name: Ahoua, title: si363, role: 0
# name: Teghan, title: si363, role: 0
# name: Jaying, title: si363, role: 0
# name: Ramanas, title: si363, role: 0
# name: Hiro, title: si363, role: 0
# name: Brendyn, title: si364, role: 1
# name: Cloe, title: si364, role: 0
# name: Shauni, title: si364, role: 0
# name: Amanda, title: si364, role: 0
# name: Aisha, title: si364, role: 0
# name: Theo, title: si364, role: 0
# name: Kenyon, title: si364, role: 0
# name: Caitaidh, title: si364, role: 0
# name: Elisau, title: si364, role: 0
# name: Yana, title: si364, role: 0
# name: Lanna, title: si364, role: 0
# name: Aara, title: si364, role: 0
# name: Rawia, title: si364, role: 0
# name: Hugo, title: si364, role: 0
# name: Atika, title: si364, role: 0
# name: Eshan, title: si364, role: 0
# name: Angel, title: si364, role: 0
# name: Maddi, title: si364, role: 0
# name: Niven, title: si364, role: 0
# name: Kathleen, title: si364, role: 0
# name: Kalyana, title: si364, role: 0
# name: Samiya, title: si364, role: 0
# name: Rayne, title: si364, role: 0
# name: Ramit, title: si364, role: 0
# name: Ellis, title: si364, role: 0
# name: Sammie, title: si364, role: 0
# name: Miao, title: si364, role: 0
# name: Penny, title: si364, role: 0
# name: Kizhi, title: si364, role: 0
# name: Alphonsina, title: si364, role: 0
# name: Limbiadhe, title: si364, role: 0
# name: Yasir, title: si364, role: 0
# name: Teos, title: si364, role: 0
# name: Thorben, title: si364, role: 0
# name: Lokesh, title: si364, role: 0
# name: Diarmaid, title: si364, role: 0
# name: Mungo, title: si364, role: 0
# name: Kizzy, title: si364, role: 0
# name: Rhein, title: si422, role: 1
# name: Keri, title: si422, role: 0
# name: Bente, title: si422, role: 0
# name: Laurie, title: si422, role: 0
# name: Rylay, title: si422, role: 0
# name: Ole, title: si422, role: 0
# name: Imogem, title: si422, role: 0
# name: Kenton, title: si422, role: 0
# name: Cruz, title: si422, role: 0
# name: Loche, title: si422, role: 0
# name: Karrah, title: si422, role: 0
# name: Ammara, title: si422, role: 0
# name: Lucian, title: si422, role: 0
# name: Dilraj, title: si422, role: 0
# name: Averon, title: si422, role: 0
# name: Cora, title: si422, role: 0
# name: Irza, title: si422, role: 0
# name: Isma, title: si422, role: 0
# name: Owais, title: si422, role: 0
# name: Turner, title: si422, role: 0
# name: Devlin, title: si422, role: 0
# name: Reese, title: si422, role: 0
# name: Dimitri, title: si422, role: 0
# name: Wojciech, title: si422, role: 0
# name: Safa, title: si422, role: 0
# name: Sol, title: si422, role: 0
# name: Kharli, title: si422, role: 0
# name: Kieya, title: si422, role: 0
# name: Alexina, title: si422, role: 0
# name: Lorenz, title: si422, role: 0
# name: Ali, title: si422, role: 0
# name: Elisabeth, title: si422, role: 0
# name: Shauna, title: si422, role: 0
# name: Navdeep, title: si422, role: 0
# name: Molly, title: si422, role: 0
# name: Nawfal, title: si422, role: 0
# name: Bailley, title: si422, role: 0
# name: Asra, title: si422, role: 0
# name: Koushik, title: si422, role: 0
# name: Alaa, title: si422, role: 0
# name: Maison, title: si422, role: 0
# name: Archie, title: si422, role: 0
# name: Hamani, title: si430, role: 1
# name: Kyler, title: si430, role: 0
# name: Mac, title: si430, role: 0
# name: Kaya, title: si430, role: 0
# name: Se, title: si430, role: 0
# name: Gus, title: si430, role: 0
# name: Takua, title: si430, role: 0
# name: Janet, title: si430, role: 0
# name: Karice, title: si430, role: 0
# name: Kerrie, title: si430, role: 0
# name: Ailise, title: si430, role: 0
# name: Kaye, title: si430, role: 0
# name: Amira, title: si430, role: 0
# name: Alexei, title: si430, role: 0
# name: Greg, title: si430, role: 0
# name: Eila, title: si430, role: 0
# name: Naima, title: si430, role: 0
# name: Mehreen, title: si430, role: 0
# name: Teiyib, title: si430, role: 0
# name: Malachy, title: si430, role: 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import json
import sqlite3

conn = sqlite3.connect('rosterdb.sqlite')
curr = conn.cursor()

#lets setup a executescrupt()

curr.executescript('''
      DROP TABLE IF EXISTS User;
      DROP TABLE IF EXISTS Course;
      DROP TABLE IF EXISTS Member;
      
      CREATE TABLE User(
          id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
          name TEXT UNIQUE
      );
      
      CREATE TABLE Course(
          id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
          title TEXT UNIQUE
      );
      
      CREATE TABLE Member(
          user_id INTEGER,
          course_id INTEGER,
          role INTEGER,
          PRIMARY KEY (user_id, course_id)
      );
''')

fname = input ('Enter the file name:')
if len(fname) < 1: fname = 'roster_data.json'
    
# [
#    ["Charley", "sill0", 1],
#    ["Mea", "sill0", 0], 

str_data = open (fname).read()
json_data = json.loads(str_data)

for entry in json_data:
    name = entry[0]
    title = entry[1]
    role = entry[2]
    
    print(f'name: {name}, title: {title}, role: {role}')
    
    curr.execute('''INSERT OR IGNORE INTO User (name)
          VALUES(?)''', (name, ))
    curr.execute('''SELECT id FROM User WHERE name = ?''', (name, ))
    user_id = curr.fetchone()[0]
    
    curr.execute('''INSERT OR IGNORE INTO Course (title)
    VALUES(?)''', (title, ))
    curr.execute('''SELECT id FROM Course WHERE title = ?''', (title, ))
    course_id = curr.fetchone()[0]
    
    curr.execute('''INSERT OR REPLACE INTO Member (user_id, course_id, role)
    VALUES(?, ?, ?)''', (user_id, course_id, role))
    
    conn.commit()
