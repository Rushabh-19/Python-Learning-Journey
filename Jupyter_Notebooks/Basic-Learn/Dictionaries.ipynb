# %% [markdown]
# <center><h1>Dictionaries</h1></center>

# %%
dir(dict())
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
purse = dict()

# %%
purse['Money']= 12
purse['Candy']=3
purse['Tissues']=75

# %%
print(purse)
# Out:
# {'Money': 12, 'Candy': 3, 'Tissues': 75}

# %%
print(purse['Candy'])
# Out:
# 3

# %%
purse['Candy'] = purse['Candy'] + 2

# %%
print(purse['Candy'])
# Out:
# 5

# %%
print(purse)
# Out:
# {'Money': 12, 'Candy': 5, 'Tissues': 75}

# %% [markdown]
# ### Difference between list() and dict()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Making a Histogram

# %%
count = dict()                                      #this is an empty dictionary
names = ['csev', 'cwen', 'csev', 'zqian', 'cwen']   #this is a list of names whose histogram to be created
for x in names:
    if x not in count:
        count[x] = 1
    else:
        count[x] += 1
print(count)
# Out:
# {'csev': 2, 'cwen': 2, 'zqian': 1}

# %% [markdown]
# ### get(x,y) method
# + Arg:   x --> key   y --> default
# + Returns: Value of the Key ; if the key exist
#          default ; if the key does not exist

# %%
names = {'csev': 2, 'cwen': 2, 'zqian': 1}

# %%
names.get('csev', -1)
# Out:
# 2

# %%
names.get('bob', -1)
# Out:
# -1

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# get() if similar to
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Making a Histogram

# %%
counts = dict()
names = ['csev', 'cwen', 'csev', 'zqian', 'cwen']
for name in names:
    counts[name] = counts.get(name , 0) + 1
print(counts)
# Out:
# {'csev': 2, 'cwen': 2, 'zqian': 1}

# %%
counts = dict()
line = 'the clown ran after the car and the car ran into the tent and the tent fell down on the clown and the car'
words = line.split()
print('words: ', words)
print('Counting...')

for word in words:
    counts[word] = counts.get(word,0) + 1
print ('counts -->' , counts)
# Out:
# words:  ['the', 'clown', 'ran', 'after', 'the', 'car', 'and', 'the', 'car', 'ran', 'into', 'the', 'tent', 'and', 'the', 'tent', 'fell', 'down', 'on', 'the', 'clown', 'and', 'the', 'car']
# Counting...
# counts --> {'the': 7, 'clown': 2, 'ran': 2, 'after': 1, 'car': 3, 'and': 3, 'into': 1, 'tent': 2, 'fell': 1, 'down': 1, 'on': 1}

# %% [markdown]
# # Loops and Dictionaries

# %%
counts = {'chuck' : 1 , 'freed' : 42 , 'jan' : 100}
for x in counts:
    print(x , counts[x])
# Out:
# chuck 1
# freed 42
# jan 100

# %% [markdown]
# # Retriving Keys and Values

# %%
jjj = {'chuck' : 1 , 'freed' : 42 , 'jan' : 100}

# %% [markdown]
# Keys-->

# %%
print(list(jjj))
# Out:
# ['chuck', 'freed', 'jan']

# %%
print(jjj.keys())
# Out:
# dict_keys(['chuck', 'freed', 'jan'])

# %% [markdown]
# Values -->

# %%
print(jjj.values())
# Out:
# dict_values([1, 42, 100])

# %% [markdown]
# Full sets -->

# %%
print(jjj.items())
# Out:
# dict_items([('chuck', 1), ('freed', 42), ('jan', 100)])

# %% [markdown]
# # Two Iteration Variables

# %%
jjj = {'chuck' : 1 , 'freed' : 42 , 'jan' : 100}
for aaa, bbb in jjj.items():
    print(aaa,bbb)
# Out:
# chuck 1
# freed 42
# jan 100

# %%
jjj = {'chuck' : 1 , 'freed' : 42 , 'jan' : 100}
for k, v in jjj.items():
    print(k,v)
# Out:
# chuck 1
# freed 42
# jan 100

# %%
fname = input('Enter the File name: ')
fh = open(fname)
#making a Histogram for counting all words with its frequency
counts = dict()
for line in fh:
    line = line.split()
    for word in line:
        counts[word] = counts.get(word,0) + 1
#finding the words with largest Frequency
bigCount = None
bigWord = None
for k,v in counts.items():
    if bigCount is None or v > bigCount:
        bigCount = v
        bigWord = k
print(bigWord , bigCount)
# Out:
# Enter the File name: mbox-short.txt
# Jan 352

# %%
stuff = dict()
print(stuff.get('candy',-1))
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
name = input("Enter file:")
if len(name) < 1:
    name = "mbox-short.txt"
handle = open(name)

counts = dict()

for line in handle:
    line = line.strip()
    if not line.startswith('From:'): continue
    line = line.split()[1]
    counts[line] = counts.get(line,0) +1

bigCount = None
userName = None

for k,v in counts.items():
    if bigCount is None or v > bigCount:
        bigCount = v
        userName = k

print(userName, bigCount)
# Out:
# Enter file:
# cwen@iupui.edu 5

# %%
passage = '''The column graph compares the changes in the proportion of population in India, China, the
USA and Japan in 1950 and 2000, and also indicates the projections for 2050. It is clear from
the graph that China had the highest percentage of world population in 1950 and 2000, but
estimates show that India will take the lead by 2050.
In 1950, China accounted for a little over a quarter of the world’s population. Although it
decreased to a little under a quarter, it was still the highest in 2000, compared to the other
three countries. It is estimated that the population of China will continue to drop and would
reach approximately19% by 2050.
India showed an opposing trend to China. The population in India in 1950 was 15%, which
was considerably lower than that of China. However, the population increased moderately
to 19% by 2000 and is further expected to grow and reach nearly 20%, which would be the
highest among the given countries by 2050.
When it comes to the population of the USA and Japan, both showed a decrease from 1950 to
2000. It is predicted that the percentage will remain the same in the USA, whereas in Japan,
the population is likely to keep falling till 2050.
Overall, Japan had the least population in the given period, and the population is expected
to decrease to approximately 3% by 2050.'''

# %%
counts = dict()
line = passage
words = line.split()
print('words: ', words)
print('Counting...')

tot_words = 0
for word in words:
    counts[word] = counts.get(word,0) + 1
    tot_words += 1
print ('counts -->' , counts)
print ('Total Number of Words -->', tot_words)
# Out:
# words:  ['The', 'column', 'graph', 'compares', 'the', 'changes', 'in', 'the', 'proportion', 'of', 'population', 'in', 'India,', 'China,', 'the', 'USA', 'and', 'Japan', 'in', '1950', 'and', '2000,', 'and', 'also', 'indicates', 'the', 'projections', 'for', '2050.', 'It', 'is', 'clear', 'from', 'the', 'graph', 'that', 'China', 'had', 'the', 'highest', 'percentage', 'of', 'world', 'population', 'in', '1950', 'and', '2000,', 'but', 'estimates', 'show', 'that', 'India', 'will', 'take', 'the', 'lead', 'by', '2050.', 'In', '1950,', 'China', 'accounted', 'for', 'a', 'little', 'over', 'a', 'quarter', 'of', 'the', 'world’s', 'population.', 'Although', 'it', 'decreased', 'to', 'a', 'little', 'under', 'a', 'quarter,', 'it', 'was', 'still', 'the', 'highest', 'in', '2000,', 'compared', 'to', 'the', 'other', 'three', 'countries.', 'It', 'is', 'estimated', 'that', 'the', 'population', 'of', 'China', 'will', 'continue', 'to', 'drop', 'and', 'would', 'reach', 'approximately19%', 'by', '2050.', 'India', 'showed', 'an', 'opposing', 'trend', 'to', 'China.', 'The', 'population', 'in', 'India', 'in', '1950', 'was', '15%,', 'which', 'was', 'considerably', 'lower', 'than', 'that', 'of', 'China.', 'However,', 'the', 'population', 'increased', 'moderately', 'to', '19%', 'by', '2000', 'and', 'is', 'further', 'expected', 'to', 'grow', 'and', 'reach', 'nearly', '20%,', 'which', 'would', 'be', 'the', 'highest', 'among', 'the', 'given', 'countries', 'by', '2050.', 'When', 'it', 'comes', 'to', 'the', 'population', 'of', 'the', 'USA', 'and', 'Japan,', 'both', 'showed', 'a', 'decrease', 'from', '1950', 'to', '2000.', 'It', 'is', 'predicted', 'that', 'the', 'percentage', 'will', 'remain', 'the', 'same', 'in', 'the', 'USA,', 'whereas', 'in', 'Japan,', 'the', 'population', 'is', 'likely', 'to', 'keep', 'falling', 'till', '2050.', 'Overall,', 'Japan', 'had', 'the', 'least', 'population', 'in', 'the', 'given', 'period,', 'and', 'the', 'population', 'is', 'expected', 'to', 'decrease', 'to', 'approximately', '3%', 'by', '2050.']
# Counting...
# counts --> {'The': 2, 'column': 1, 'graph': 2, 'compares': 1, 'the': 23, 'changes': 1, 'in': 10, 'proportion': 1, 'of': 6, 'population': 9, 'India,': 1, 'China,': 1, 'USA': 2, 'and': 9, 'Japan': 2, '1950': 4, '2000,': 3, 'also': 1, 'indicates': 1, 'projections': 1, 'for': 2, '2050.': 6, 'It': 3, 'is': 6, 'clear': 1, 'from': 2, 'that': 5, 'China': 3, 'had': 2, 'highest': 3, 'percentage': 2, 'world': 1, 'but': 1, 'estimates': 1, 'show': 1, 'India': 3, 'will': 3, 'take': 1, 'lead': 1, 'by': 5, 'In': 1, '1950,': 1, 'accounted': 1, 'a': 5, 'little': 2, 'over': 1, 'quarter': 1, 'world’s': 1, 'population.': 1, 'Although': 1, 'it': 3, 'decreased': 1, 'to': 11, 'under': 1, 'quarter,': 1, 'was': 3, 'still': 1, 'compared': 1, 'other': 1, 'three': 1, 'countries.': 1, 'estimated': 1, 'continue': 1, 'drop': 1, 'would': 2, 'reach': 2, 'approximately19%': 1, 'showed': 2, 'an': 1, 'opposing': 1, 'trend': 1, 'China.': 2, '15%,': 1, 'which': 2, 'considerably': 1, 'lower': 1, 'than': 1, 'However,': 1, 'increased': 1, 'moderately': 1, '19%': 1, '2000': 1, 'further': 1, 'expected': 2, 'grow': 1, 'nearly': 1, '20%,': 1, 'be': 1, 'among': 1, 'given': 2, 'countries': 1, 'When': 1, 'comes': 1, 'Japan,': 2, 'both': 1, 'decrease': 2, '2000.': 1, 'predicted': 1, 'remain': 1, 'same': 1, 'USA,': 1, 'whereas': 1, 'likely': 1, 'keep': 1, 'falling': 1, 'till': 1, 'Overall,': 1, 'least': 1, 'period,': 1, 'approximately': 1, '3%': 1}
# Total Number of Words --> 232
